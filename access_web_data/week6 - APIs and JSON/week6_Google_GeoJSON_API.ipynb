# %%
#example code

import urllib.request, urllib.parse, urllib.error
import json

# Note that Google is increasingly requiring keys
# for this API
serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    url = serviceurl + urllib.parse.urlencode(
        {'address': address})

    print('Retrieving', url)
    uh = urllib.request.urlopen(url)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)

# %%
# actual assignment code

import urllib.request, urllib.parse, urllib.error
import json

serviceurl = "http://py4e-data.dr-chuck.net/geojson?"

address = input("Enter your location:")

url = serviceurl + urllib.parse.urlencode(
    {'address': address})

print('Retrieving', url)
urlhandle = urllib.request.urlopen(url)
data = urlhandle.read().decode() #decode utf8 from the outside world ;-)
print('Retrieving', len(data), 'characters')
json_dict = json.loads(data)
print("Place_id:", json_dict['results'][0]['place_id'])
#print(json.dumps(json_dict, indent=4))
# Out:
# Enter your location:Indian School of Mines Dhanbad
# Retrieving http://py4e-data.dr-chuck.net/geojson?address=Indian+School+of+Mines+Dhanbad
# Retrieving 1765 characters
# Place_id: ChIJbfzMBAij9jkR52T3hRseFfo
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dhanbad",
#                     "short_name": "Dhanbad",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Dhanbad",
#                     "short_name": "Dhanbad",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Jharkhand",
#                     "short_name": "JH",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "India",
#                     "short_name": "IN",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Dhanbad, Jharkhand, India",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 23.854128,
#                         "lng": 86.5023994
#                     },
#                     "southwest": {
#                         "lat": 23.7499772,
#                         "lng": 86.36610019999999
#                     }
#                 },
#                 "location": {
#                     "lat": 23.7956531,
#                     "lng": 86.43038589999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.854128,
#                         "lng": 86.5023994
#                     },
#                     "southwest": {
#                         "lat": 23.7499772,
#                         "lng": 86.36610019999999
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJbfzMBAij9jkR52T3hRseFfo",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
